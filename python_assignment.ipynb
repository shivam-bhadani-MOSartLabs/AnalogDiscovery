# %% [markdown]
# ### 1. Variable Scope & Mutable Defaults
#
# What does this print?
#
# ```py
# def add_item(item, lst=[]):
#     lst.append(item)
#     return lst
#
# print(add_item(1))
# print(add_item(2))
# ```
# ### 2. Operator Precedence & Chaining
#
# What is the output of this?
# ```py
# x = 2
# y = 3
# z = 4
# print(x + y * z ** 2 // y - z)
# ```
# ### 3. Complex Loop Logic
#
# What does this print?
# ```py
# for i in range(3):
#     for j in range(i):
#         if i + j == 2:
#             break
#         print(i, j)
# ```
# ### 4. Recursion with Edge Case
#
# What is the result of weird(5)?
# ```py
# def weird(n):
#     if n <= 1:
#         return n
#     return weird(n-1) + weird(n-2) + 1
# ```
# ### 5. List & Dictionary Mutation
#
# What is printed?
# ```py
# a = [1, 2]
# b = [a, a]
# b[0].append(3)
# print(b)
# ```
# ### 6. String & Slice Oddity
#
# What does this print?
# ```py
# s = "Python"
# print(s[::-2][1:3])
# ```
# ### 7. Class Attributes vs Instance Attributes
#
# What will this print?
# ```py
# class Counter:
#     count = 0
#     def __init__(self):
#         self.count += 1
#
# a = Counter()
# b = Counter()
# print(a.count, b.count, Counter.count)
# ```
# ### 8. Class & Mutable Class Attributes
#
# What does this print?
# ```py
# class Tracker:
#     items = []
#
#     def add(self, item):
#         self.items.append(item)
#
# a = Tracker()
# b = Tracker()
# a.add(1)
# b.add(2)
# print(a.items, b.items)
# ```
# ### 9. Recursive Function with Conditional Twist
#
# What is returned by mystery(6)?
# ```py
# def mystery(n):
#     if n <= 1:
#         return 1
#     if n % 2 == 0:
#         return n * mystery(n-1)
#     return mystery(n-1) + 1
# ```
# ### 10. Complex Loop & List Behavior
#
# What is printed?
# ```py
# lst = [0, 1, 2, 3]
# for i in lst:
#     lst.append(i + 4)
#     if len(lst) > 8:
#         break
# print(lst)
# ```

# %% [markdown]
# **explain your expected solution then run the code snippet to verify it, and then explain your understanding*
